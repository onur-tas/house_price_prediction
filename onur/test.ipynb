# %%
import pandas as pd

# %%
df = pd.read_csv('../clustered_data_v2.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_lot_normalized  floors  waterfront  \
# 0      221900.0         3       1.00             8.639588     1.0           0
# 1      538000.0         3       2.25             8.887791     2.0           0
# 2      180000.0         2       1.00             9.210440     1.0           0
# 3      604000.0         4       3.00             8.517393     1.0           0
# 4      510000.0         3       2.00             8.997271     1.0           0
# ...         ...       ...        ...                  ...     ...         ...
# 21608  360000.0         3       2.50             7.031741     3.0           0
# 21609  400000.0         4       2.50             8.668024     2.0           0
# 21610  402101.0         2       0.75             7.208600     2.0           0
# 21611  400000.0         3       2.50             7.778630     2.0           0
# 21612  325000.0         2       0.75             6.981935     2.0           0
#
# ...

# %%
df2 = pd.read_csv('../cleaned_data.csv')

# %%
df2
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650     1.0           0     0          3      7
# ...

# %%
import joblib

# %%
model_cluster_0 = joblib.load("../model_cluster_0.joblib")

# %%
scaler_grade_living_cluster_0 = joblib.load("../scaler_grade_living_cluster_0.pkl")

# %%
specific_features = ['grade_living_normalized', 'lat','nearest_station_distance_km']  # Example of top 3 features

# %%
# Assuming you have already loaded the scaler and defined model_cluster_0
# Load the scaler from the file
scaler_grade_living_cluster_0 = joblib.load('../scaler_grade_living_cluster_0.pkl')

# Assuming df is your original DataFrame
row = 20

grade_living = df['grade_living_normalized'].iloc[row]
lat =  df['lat'].iloc[row]
distance_to_station = df['nearest_station_distance_km'].iloc[row]
cluster_0_inputs = {
            'grade_living_normalized': [grade_living],
            'lat': [lat],
            'nearest_station_distance_km': [distance_to_station]
        }

# Convert dictionary to DataFrame
cluster_0_inputs_df = pd.DataFrame(cluster_0_inputs)

# Transform the features using the loaded scaler
cluster_0_inputs_scaled = scaler_grade_living_cluster_0.transform(cluster_0_inputs_df)
print(cluster_0_inputs_scaled)
predicted_price = model_cluster_0.predict(cluster_0_inputs_scaled)
print(predicted_price)
# Out:
# [[-0.81163244  1.02471003 -1.37110992]]
# [20664.787]
